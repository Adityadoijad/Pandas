# %% [markdown]
# #### Adding a new column

# %%
import pandas as pd
import numpy as np

# %%
my_df =pd.read_csv('dog_data_short.csv')
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip
# 0             COCKAPOO        BROWN  CHARLEY     15236
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238
# 2        BELG MALINOIS      BRINDLE     EICH     15238
# 3                MIXED  BLACK/BROWN    ARROW     15104
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139

# %%
# add column from list
gender =["male","male","female","male","female"]  # NOTE this must match the no. of rows
my_df["gender"] = gender
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  gender
# 0             COCKAPOO        BROWN  CHARLEY     15236    male
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238    male
# 2        BELG MALINOIS      BRINDLE     EICH     15238  female
# 3                MIXED  BLACK/BROWN    ARROW     15104    male
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  female

# %%
# add default values
my_df['Alive']=[True]*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  gender  Alive
# 0             COCKAPOO        BROWN  CHARLEY     15236    male   True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238    male   True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  female   True
# 3                MIXED  BLACK/BROWN    ARROW     15104    male   True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  female   True

# %%
# add nan(null) value
my_df["show dog"]= [np.nan]*len(my_df)
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  gender  Alive  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    male   True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238    male   True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  female   True
# 3                MIXED  BLACK/BROWN    ARROW     15104    male   True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  female   True
#
#    show dog
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# add column with .inser() - allows position 
my_df.insert(1,"Adoptedd",[True]*len(my_df))
my_df
# Out:
#                  Breed  Adoptedd        Color  DogName  OwnerZip  gender  \
# 0             COCKAPOO      True        BROWN  CHARLEY     15236    male
# 1         GER SHEPHERD      True  BLACK/BROWN   TACODA     15238    male
# 2        BELG MALINOIS      True      BRINDLE     EICH     15238  female
# 3                MIXED      True  BLACK/BROWN    ARROW     15104    male
# 4  AM PIT BULL TERRIER      True  WHITE/BROWN   OAKLEY     15139  female
#
#    Alive  show dog
# 0   True       NaN
# 1   True       NaN
# 2   True       NaN
# 3   True       NaN
# 4   True       NaN

# %%
# add column with assign 
my_df =my_df.assign(Horse=[False]*len(my_df))
my_df
# Out:
#                  Breed  Adoptedd        Color  DogName  OwnerZip  gender  \
# 0             COCKAPOO      True        BROWN  CHARLEY     15236    male
# 1         GER SHEPHERD      True  BLACK/BROWN   TACODA     15238    male
# 2        BELG MALINOIS      True      BRINDLE     EICH     15238  female
# 3                MIXED      True  BLACK/BROWN    ARROW     15104    male
# 4  AM PIT BULL TERRIER      True  WHITE/BROWN   OAKLEY     15139  female
#
#    Alive  show dog  Horse
# 0   True       NaN  False
# 1   True       NaN  False
# 2   True       NaN  False
# 3   True       NaN  False
# 4   True       NaN  False

# %% [markdown]
# #### Remove columns and rows

# %%
#delete permenantly # remove column

my_df.drop("Adoptedd", axis=1, inplace=True)
# NOTE: axis=0 is for row
# NOTE: column is not deleted from csv file

# %%
# show dataframe again
my_df
# Out:
#                  Breed        Color  DogName  OwnerZip  gender  Alive  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    male   True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238    male   True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  female   True
# 3                MIXED  BLACK/BROWN    ARROW     15104    male   True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  female   True
#
#    show dog  Horse
# 0       NaN  False
# 1       NaN  False
# 2       NaN  False
# 3       NaN  False
# 4       NaN  False

# %%
# remove row
my_df.drop(3 ,axis=0)
# Out:
#                  Breed        Color  DogName  OwnerZip  gender  Alive  \
# 0             COCKAPOO        BROWN  CHARLEY     15236    male   True
# 1         GER SHEPHERD  BLACK/BROWN   TACODA     15238    male   True
# 2        BELG MALINOIS      BRINDLE     EICH     15238  female   True
# 4  AM PIT BULL TERRIER  WHITE/BROWN   OAKLEY     15139  female   True
#
#    show dog  Horse
# 0       NaN  False
# 1       NaN  False
# 2       NaN  False
# 4       NaN  False
