# %% [markdown]
# #### How To Fix Incomplete Data

# %%
import pandas as pd
import numpy as np
# create dummy data
stuff= {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,8,9] ,'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
#drop rows with null data
my_df.dropna()
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %%
# drop columns with null data
my_df.dropna(axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
#not permanant, inplace=True
# my_df.dropna(inplace=True)

# %%
# more than one? set threshold
stuff= {'A':[1,2,3], 'B':[4,np.nan,np.nan], 'C':[7,8,9] ,'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df

my_df.dropna(thresh=2,axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
#replace null_data with fillna()
my_df.fillna(value=-9999999)
# Out:
#    A          B  C   D
# 0  1        4.0  7  10
# 1  2 -9999999.0  8  11
# 2  3 -9999999.0  9  12

# %%
#use math function
stuff= {'A':[1,2,3], 'B':[4,np.nan,6], 'C':[7,8,9] ,'D':[10,11,12]}
my_df = pd.DataFrame(stuff)
my_df
my_df.fillna(value=my_df['B'].mean())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  5.0  8  11
# 2  3  6.0  9  12

# %%
#use min max
my_df.fillna(value=my_df['B'].min())
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  4.0  8  11
# 2  3  6.0  9  12

# %%
#use sum
my_df.fillna(value=my_df['B'].sum())
# Out:
#    A     B  C   D
# 0  1   4.0  7  10
# 1  2  10.0  8  11
# 2  3   6.0  9  12
